# 6                irregular     68                      4               3
# 7                  regular     63                      6               3
# 8                  regular     69                      6              10
# 9                irregular     65                      4               2
# 10                 regular     73                      6               8
# 11               irregular     63                      2               3
# 12               irregular     82                      4               6
# 13               irregular     73                      4               9
# 14                 regular     69                      2               6
# 15               irregular     68                      6              30
# 16                 regular     66                      4               7
# 17               irregular     72                      2              10
# 18                 regular     63                      6               4
# 19                 regular     72                      2              11
# 20               irregular     75                      4              14
# 21               irregular     77                      2              12
# 22               irregular     70                      2               4
# 23               irregular    101                      6               9
# 24                 regular     62                      4               6
# 25                 regular     81                      6              12
# 26               irregular     88                      6              11
# 27               irregular     65                      4               2
# 28                 regular     75                      6               1
# 29               irregular     66                      2               5
# ..                     ...    ...                    ...             ...
# 469              irregular     66                      6               4
# 470                regular     70                      4               9
# 471                regular     72                      2               6
# 472                regular     72                      2              12
# 473                regular     93                      6              11
# 474                regular     59                      4               2
# 475                regular     88                      6               1
# 476              irregular     63                      6               5
# 477              irregular     61                      4               2
# 478                regular     65                      6              15
# 479                regular     63                      2               3
# 480              irregular     75                      4               3
# 481                regular     70                      4              10
# 482                regular     74                      2               5
# 483              irregular     52                      6               2
# 484                regular     89                      4               1
# 485              irregular     73                      2               5
# 486                regular     87                      6               2
# 487                regular     76                      2              15
# 488              irregular     77                      4               3
# 489              irregular     79                      2               3
# 490                regular     87                      2              10
# 491              irregular     75                      6               2
# 492                regular     91                      4               8
# 493              irregular     62                      6               3
# 494                regular     59                      6               6
# 495                regular     86                      4               9
# 496                regular     68                      6               6
# 497              irregular     61                      2              30
# 498              irregular     70                      6               7
#
# [499 rows x 9 columns]

# %%
dataset.isnull().any()
# Out:
# date                        False
# location                    False
# age                         False
# disease                     False
# sevearity_of_the_disease    False
# frequency_of_suffering      False
# pulse                       False
# duration_of_suffering       False
# length_of_stay              False
# dtype: bool

# %%
x = dataset.iloc[:, 2:8].values
y = dataset.iloc[:, 8].values

# %%
x
# Out:
# array([[42, 'heartstroke', 'high', 'regural', 96, 6],
#        [41, 'cancer', 'low', 'irregular', 61, 2],
#        [42, 'heartstroke', 'moderate', 'irregular', 64, 4],
#        ...,
#        [32, 'bone fracture', 'high', 'regular', 68, 6],
#        [40, 'fever', 'low', 'irregular', 61, 2],
#        [26, 'fever', 'moderate', 'irregular', 70, 6]], dtype=object)

# %%
y
# Out:
# array([ 3,  2,  1,  5,  2,  7,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,  7,
#        10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,  3,
#        10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,  6,
#        12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  1,  5,  2, 15,  3,  3,
#        10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,  6,
#        12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,
#         7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,
#         3, 10,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,
#         7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,
#         3, 10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,
#         6, 12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  1,  5,  2, 15,  3,
#         3, 10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,
#         6, 12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,  6,  9,  6,
#        30,  7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,  2, 15,
#         3,  3, 10,  5,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,  6,  9,
#         6, 30,  7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,  2,
#        15,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14, 12,
#         4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  1,  5,  2,
#        15,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14, 12,
#         4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,  6,
#         9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,
#         2, 15,  3,  3, 10,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,  6,
#         9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,  5,
#         2, 15,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14,
#        12,  4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  1,  5,
#         2, 15,  3,  3, 10,  2,  8,  3,  6,  9,  6, 30,  7, 10,  4, 11, 14,
#        12,  4,  9,  6, 12, 11,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,  3,
#         6,  9,  6, 30,  7, 10,  4, 11, 14, 12,  4,  9,  6, 12, 11,  2,  1,
#         5,  2, 15,  3,  3, 10,  5,  2,  1,  5,  2, 15,  3,  3, 10,  2,  8,
#         3,  6,  9,  6, 30,  7], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder

#Label Encoding

labelencoder_X = LabelEncoder()
x[:, 1] = labelencoder_X.fit_transform(x[:,1])
labelencoder_X2 = LabelEncoder()
x[:, 2] = labelencoder_X2.fit_transform(x[:,2])
labelencoder_X3 = LabelEncoder()
x[:, 3] = labelencoder_X3.fit_transform(x[:,3])

# %%
x
# Out:
# array([[42, 4, 0, 2, 96, 6],
#        [41, 2, 1, 0, 61, 2],
#        [42, 4, 2, 0, 64, 4],
#        ...,
#        [32, 1, 0, 1, 68, 6],
#        [40, 3, 1, 0, 61, 2],
#        [26, 3, 2, 0, 70, 6]], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder(categorical_features = [1])
x = onehotencoder.fit_transform(x).toarray()
x=x[:,1:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
x.shape
# Out:
# (499, 9)

# %%
onehotencoder = OneHotEncoder(categorical_features = [6])
x = onehotencoder.fit_transform(x).toarray()
x=x[:,1:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
x
# Out:
# array([[ 0.,  1.,  0., ...,  0., 96.,  6.],
#        [ 0.,  0.,  0., ...,  1., 61.,  2.],
#        [ 0.,  0.,  0., ...,  2., 64.,  4.],
#        ...,
#        [ 1.,  0.,  1., ...,  0., 68.,  6.],
#        [ 0.,  0.,  0., ...,  1., 61.,  2.],
#        [ 0.,  0.,  0., ...,  2., 70.,  6.]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
# array([[ 0.,  0.,  1., ...,  1., 64.,  2.],
#        [ 1.,  0.,  1., ...,  1., 77.,  2.],
#        [ 1.,  0.,  1., ...,  1., 88.,  2.],
#        ...,
#        [ 0.,  0.,  0., ...,  0., 71.,  6.],
#        [ 0.,  0.,  1., ...,  1., 73.,  2.],
#        [ 1.,  0.,  1., ...,  1., 95.,  2.]])

# %%
y_train
# Out:
# array([12,  3,  3, 11,  3,  6,  2,  2,  3,  2, 15,  3, 10, 10,  2, 30,  3,
#        10,  2, 10, 10,  9,  6,  5,  8,  3,  3,  4,  5,  9,  1,  9,  2,  5,
#        11,  3,  8,  2,  2,  3,  6, 11,  6, 11, 15,  2, 10,  5,  2,  7, 12,
#        12, 30,  8,  1,  4, 10, 14,  9,  6,  3, 11,  2, 11, 12, 12,  1,  2,
#         7,  9,  3,  6,  2,  1,  9, 11,  4, 12, 15,  2,  2,  4, 14,  3,  5,
#         7, 15, 10, 11,  5,  3,  5,  3, 15,  3,  3,  3,  3,  4,  4, 12,  6,
#         2, 15, 12,  6,  6, 10,  3, 10,  6, 14, 30,  3,  1, 14, 10, 11, 10,
#         4,  2,  1,  3, 10, 12,  2,  2, 15,  2,  4,  2, 10, 14, 11,  2,  3,
#        30,  7,  8, 11,  2,  3,  6,  3, 11,  3, 11, 11,  9,  3,  1,  7, 10,
#         4,  3, 12,  2, 11,  2,  6,  9,  2,  1,  5,  3,  9, 12,  3,  2,  6,
#         4,  8, 12, 10,  4,  3,  4,  7,  4,  9,  2, 11,  2, 10,  6,  1,  4,
#         3,  6,  8, 10,  2, 12, 14,  5,  3,  6,  3,  9, 11,  6,  6,  9, 14,
#        12,  3,  4, 30,  9,  6,  2,  6,  5,  3,  7,  9,  9,  6, 11, 15, 11,
#         2,  7,  6,  6,  3,  6, 11,  5,  1, 14,  4,  5, 12, 15,  9, 11, 10,
#         2,  6,  5, 10,  2,  6,  1, 12, 14,  3, 10,  3,  8, 11, 12,  8,  3,
#         3, 30,  5,  6,  5,  4, 10,  1,  5,  7,  1, 15,  8,  3,  9, 10, 11,
#         3, 12,  3,  2,  6,  4,  5,  2,  3, 10, 30, 10, 11,  2, 14,  9,  2,
#         2,  4,  6,  6,  2,  6, 12,  1,  9,  3, 10,  5,  3, 11, 30, 12,  9,
#         9,  6,  2, 10,  6,  6,  3,  9, 15,  4, 11,  3, 15,  6, 15, 14,  7,
#        30,  6,  7, 11,  2,  7,  3,  4,  6,  1,  2,  3, 30, 10,  9,  1,  5,
#         2, 10, 15,  5,  4, 15,  3,  3, 15,  4,  1, 12,  1,  3, 10,  2,  4,
#         4, 15,  9,  3,  2,  8, 10, 10,  1, 10,  5, 10,  6,  6,  3, 12, 11,
#         8,  5,  1,  5,  9,  9,  9,  2,  1, 12,  8,  2, 12,  2,  8, 15,  2,
#         3, 30,  8,  4,  6, 15, 12, 11], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr=LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
],
#        [  1.,   0.,   0.,   1.,   0.,   0.,  42.,   0.,  60.,   6.],
#        [  0.,   0.,   0.,   0.,   1.,   0.,   8.,   2.,  66.,   4.],
#        [  1.,   0.,   0.,   1.,   0.,   0.,  45.,   0.,  70.,   6.]])

# %%
y_pred
# Out:
# array([7.35000845, 7.96105362, 6.79866157, 6.27949315, 6.88903537,
#        6.69625948, 7.4178671 , 6.80565202, 7.40426469, 6.72719614,
#        7.47023904, 6.93431006, 7.24290443, 8.07428472, 8.26372548,
#        8.82938012, 6.90878657, 7.22960107, 7.89725616, 7.33384905,
#        8.1324821 , 6.73693902, 7.02099675, 8.19040223, 7.34687042,
#        8.65331271, 6.89326442, 7.15253063, 6.86538347, 7.99219194,
#        5.96974695, 7.32417968, 8.58278421, 6.48248156, 7.18818907,
#        7.05318134, 8.29458993, 7.69911529, 7.64146091, 7.64413983,
#        6.89006531, 7.62717191, 6.9234873 , 8.14739437, 6.89085993,
#        6.93972763, 7.63213328, 8.70259368, 8.10744795, 7.62537997,
#        6.5284108 , 7.67118863, 6.96390743, 7.88210442, 7.79218974,
#        7.35326663, 7.03431523, 7.71667691, 7.34561179, 6.93409647,
#        7.34247376, 6.15212725, 7.2432936 , 6.74249533, 7.1460977 ,
#        7.11282767, 8.08091799, 7.19876647, 7.4876161 , 8.3829407 ,
#        6.7343362 , 7.25513726, 7.73810057, 7.14660811, 8.38342815,
#        7.73923731, 6.89495788, 6.83180118, 8.61006173, 8.28422423,
#        7.43638987, 8.07974326, 6.80366093, 5.72982717, 8.61240514,
#        7.76372059, 7.60195611, 7.34300773, 6.40917209, 7.52831248,
#        7.37788021, 6.57111336, 7.41965066, 8.27001489, 6.22924199,
#        7.91877823, 5.7781609 , 7.28182943, 7.56032025, 7.3726992 ])

# %%
y_test
# Out:
# array([ 2,  9,  7,  9,  2, 30, 30,  3,  9,  3,  5,  2,  3,  4, 12,  2, 14,
#         2, 10,  3, 12,  2, 10,  4, 11,  7, 12, 15,  8,  2, 11,  3,  2,  3,
#        15, 15,  8,  6, 12,  3, 12, 14, 30, 30,  7,  2,  3,  6,  2,  7,  2,
#         6, 30,  6,  6,  6, 11,  2,  4,  2,  4,  2, 12,  5, 10,  7,  8,  7,
#         2, 30,  4, 15,  6, 15,  5, 10,  9,  6, 10,  1,  3,  5,  2,  9,  1,
#        12,  9,  3, 14,  1,  6,  6, 10, 14,  3, 14,  2,  4, 10,  1],
#       dtype=int64)

# %%
mlr.intercept_
# Out:
# 7.242818944640025

# %%
x_train.shape
# Out:
# (399, 10)

# %%
mlr.coef_
# Out:
# array([ 0.27179295, -5.08813056,  0.79545324,  0.82254065,  0.46348896,
#         1.07992336, -0.04570187, -0.47460615,  0.02279754, -0.08394947])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# -0.01767735887582167

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-86e1b10703d2> in <module>
# ----> 1 accuracy_score(y_test,y_pred)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
